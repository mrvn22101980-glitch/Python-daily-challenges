# %%
student_name = input("Enter your name: ")
student_age = int(input("Enter your age: "))
favourite_subjects = ["Math", "Science", "English"]
# Out:
# Enter your name: Revathy
# Enter your age: 29

# %%
print("\n--- Student Profile ---")
print(f"Name: {student_name}")
print(f"Age: {student_age}")
print(f"Favourite Subjects: {', '.join(favourite_subjects)}")
# Out:
# --- Student Profile ---
# Name: Revathy
# Age: 29
# Favourite Subjects: Math, Science, English

# %%
new_subject = input("\nEnter your favourite subject to add: ")
favourite_subjects.append(new_subject)
# Out:
# Enter your favourite subject to add: English

# %%
print("\n--- Updated Student Profile ---")
print(f"Name: {student_name}")
print(f"Age: {student_age}")
print(f"Favourite Subjects: {', '.join(favourite_subjects)}")
# Out:
# --- Updated Student Profile ---
# Name: Revathy
# Age: 29
# Favourite Subjects: Math, Science, English, English, English
