# %% [markdown]
# <a href="https://colab.research.google.com/github/mrvn22101980-glitch/Python-daily-challenges/blob/main/python_day_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# 1. Create a list of 10 random exam scores (0–100) using list comprehension
scores = [random.randint(0, 100) for _ in range(10)]
print("Exam Scores:", scores)

# 2. Display each score with its index using enumerate
print("\nScores with Index:")
for index, score in enumerate(scores):
    print(f"Index {index}: Score = {score}")

# 3. Find all scores greater than 75 and display them
high_scores = [score for score in scores if score > 75]
print("\nScores greater than 75:", high_scores)

# 4. Calculate and display the average score
average_score = sum(scores) / len(scores)
print(f"\nAverage Score: {average_score:.2f}")
# Out:
# Exam Scores: [38, 87, 82, 85, 93, 20, 34, 46, 9, 49]
#
# Scores with Index:
# Index 0: Score = 38
# Index 1: Score = 87
# Index 2: Score = 82
# Index 3: Score = 85
# Index 4: Score = 93
# Index 5: Score = 20
# Index 6: Score = 34
# Index 7: Score = 46
# Index 8: Score = 9
# Index 9: Score = 49
#
# Scores greater than 75: [87, 82, 85, 93]
#
# Average Score: 54.30
