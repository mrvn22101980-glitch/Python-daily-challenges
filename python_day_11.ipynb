# %% [markdown]
# <a href="https://colab.research.google.com/github/mrvn22101980-glitch/Python-daily-challenges/blob/main/python_day_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CONSTANT DATA (Using tuple)
CLASSES = ("Class 1", "Class 2", "Class 3", "Class 4")

# STORAGE FOR STUDENTS
students = []


# FUNCTION: Add a student

def add_student():
    try:
        name = input("Enter student name: ")
        age = int(input("Enter age: "))
        class_name = input(f"Enter class {CLASSES}: ")

        if class_name not in CLASSES:
            print("Invalid class name!")
            return

        grades = float(input("Enter grade (0–100): "))

        student = {
            "name": name,
            "age": age,
            "class": class_name,
            "grade": grades
        }

        students.append(student)
        print("Student added successfully!")

    except ValueError:
        print("Invalid input! Try again.")

# %%
def delete_student():
    name = input("Enter name of student to delete: ")
    for student in students:
        if student["name"].lower() == name.lower():
            students.remove(student)
            print("Student removed!")
            return
    print("Student not found.")

# %%
def update_student():
    name = input("Enter student name to update: ")

    for student in students:
        if student["name"].lower() == name.lower():
            print("1. Update Age")
            print("2. Update Class")
            print("3. Update Grade")

            choice = int(input("Choose option: "))

            if choice == 1:
                student["age"] = int(input("Enter new age: "))
            elif choice == 2:
                class_name = input(f"Enter class {CLASSES}: ")
                if class_name in CLASSES:
                    student["class"] = class_name
                else:
                    print("Invalid class!")
            elif choice == 3:
                student["grade"] = float(input("Enter new grade: "))
            else:
                print("Invalid option.")

            print("Student updated!")
            return

    print("Student not found.")

# %%
def search_student():
    name = input("Enter student name to search: ")

    for student in students:
        if student["name"].lower() == name.lower():
            print(student)
            return
    print("Student not found.")

# %%
def categorize_grade(grade):
    if grade >= 90:
        return "Excellent"
    elif grade >= 75:
        return "Good"
    elif grade >= 50:
        return "Average"
    else:
        return "Poor"

# %%
def student_report():
    print("1. Sort by Name")
    print("2. Sort by Grade (High to Low)")
    print("3. Sort by Age")

    choice = int(input("Choose sorting option: "))

    if choice == 1:
        sorted_list = sorted(students, key=lambda x: x["name"])
    elif choice == 2:
        sorted_list = sorted(students, key=lambda x: x["grade"], reverse=True)
    elif choice == 3:
        sorted_list = sorted(students, key=lambda x: x["age"])
    else:
        print("Invalid choice.")
        return

    for s in sorted_list:
        print(f"{s['name']} - {s['grade']} - {categorize_grade(s['grade'])}")

# %%
def save_data():
    import json
    with open("students.json", "w") as f:
        json.dump(students, f)
    print("Data saved!")


def load_data():
    import json
    try:
        with open("students.json", "r") as f:
            data = json.load(f)
            students.extend(data)
        print("Data loaded successfully!")
    except FileNotFoundError:
        print("No previous data found.")

# %%
load_data()

while True:
    print("\n===== STUDENT MANAGEMENT SYSTEM =====")
    print("1. Add Student")
    print("2. Delete Student")
    print("3. Update Student")
    print("4. Search Student")
    print("5. Student Report")
    print("6. Save and Exit")

    try:
        option = int(input("Choose an option: "))

        if option == 1:
            add_student()
        elif option == 2:
            delete_student()
        elif option == 3:
            update_student()
        elif option == 4:
            search_student()
        elif option == 5:
            student_report()
        elif option == 6:
            save_data()
            print("Exiting program...")
            break
        else:
            print("Invalid option. Try again.")

    except ValueError:
        print("Please enter a valid number.")
# Out:
# No previous data found.
#
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. Delete Student
# 3. Update Student
# 4. Search Student
# 5. Student Report
# 6. Save and Exit
# Choose an option: 1
# Enter student name: nithilan
# Enter age: 8
# Enter class ('Class 1', 'Class 2', 'Class 3', 'Class 4'): 2
# Invalid class name!
#
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. Delete Student
# 3. Update Student
# 4. Search Student
# 5. Student Report
# 6. Save and Exit
# Choose an option: 1
# Enter student name: nikhilan
# Enter age: 7
# Enter class ('Class 1', 'Class 2', 'Class 3', 'Class 4'): 1
# Invalid class name!
#
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. Delete Student
# 3. Update Student
# 4. Search Student
# 5. Student Report
# 6. Save and Exit
# Choose an option: 3
# Enter student name to update: vaishu
# Student not found.
#
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. Delete Student
# 3. Update Student
# 4. Search Student
# 5. Student Report
# 6. Save and Exit
# Choose an option: 4
# Enter student name to search: revathy
# Student not found.
#
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. Delete Student
# 3. Update Student
# 4. Search Student
# 5. Student Report
# 6. Save and Exit
# Choose an option: 1
# Enter student name: nithilan
# Enter age: 8
# Enter class ('Class 1', 'Class 2', 'Class 3', 'Class 4'): 2
# Invalid class name!
#
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. Delete Student
# 3. Update Student
# 4. Search Student
# 5. Student Report
# 6. Save and Exit
# Choose an option: 5
# 1. Sort by Name
# 2. Sort by Grade (High to Low)
# 3. Sort by Age
# Choose sorting option: 2
#
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. Delete Student
# 3. Update Student
# 4. Search Student
# 5. Student Report
# 6. Save and Exit
# Choose an option: 3
# Enter student name to update: madhu
# Student not found.
#
# ===== STUDENT MANAGEMENT SYSTEM =====
# 1. Add Student
# 2. Delete Student
# 3. Update Student
# 4. Search Student
# 5. Student Report
# 6. Save and Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3120635953.py in <cell line: 0>()
#      11
#      12     try:
# ---> 13         option = int(input("Choose an option: "))
#      14
#      15         if option == 1:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
