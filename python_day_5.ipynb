# %% [markdown]
# <a href="https://colab.research.google.com/github/mrvn22101980-glitch/Python-daily-challenges/blob/main/python_day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
grades = {
    "Vijay": 85,
    "Ajith": 90,
    "Surya": 78
}

print("Initial Grades:", grades)
# Out:
# Initial Grades: {'Vijay': 85, 'Ajith': 90, 'Surya': 78}

# %%
print("\n--- Update/Add Grades for 3 Students ---")
for i in range(3):
    name = input(f"Enter student name #{i+1}: ")
    grade = int(input(f"Enter grade for {name}: "))
    grades[name] = grade   # Adds new or updates existing
    print(f"Grade updated for {name}!")

print("\nFinal Grades Dictionary:", grades)
# Out:
# --- Update/Add Grades for 3 Students ---
# Enter student name #1: Revathy
# Enter grade for Revathy: 98
# Grade updated for Revathy!
# Enter student name #2: Vaishali
# Enter grade for Vaishali: 88
# Grade updated for Vaishali!
# Enter student name #3: Madhu
# Enter grade for Madhu: 76
# Grade updated for Madhu!
#
# Final Grades Dictionary: {'Vijay': 85, 'Ajith': 90, 'Surya': 78, 'Revathy': 98, 'Vaishali': 88, 'Madhu': 76}

# %%
print("\n--- Enter at least 3 Hobbies ---")
hobbies = set()
for i in range(3):
    hobby = input(f"Enter hobby #{i+1}: ")
    hobbies.add(hobby)

print("\nHobbies Set:", hobbies)
# Out:
# --- Enter at least 3 Hobbies ---
# Enter hobby #1: Singing
# Enter hobby #2: Dancing
# Enter hobby #3: Reading Books
#
# Hobbies Set: {'Dancing', 'Reading Books', 'Singing'}

# %%
hobby_frozenset = frozenset(hobbies)
print("\nHobbies Frozenset (Immutable):", hobby_frozenset)
# Out:
# Hobbies Frozenset (Immutable): frozenset({'Dancing', 'Reading Books', 'Singing'})
